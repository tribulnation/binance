# %%
from binance import Binance
from dotenv import load_dotenv

load_dotenv()

client = Binance.new()

# %%
await client.wallet.capital.coins()
# Out:
# [{'coin': 'AGLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Adventure Gold',
#   'free': Decimal('0'),
#   'locked': Decimal('0'),
#   'freeze': Decimal('0'),
#   'withdrawing': Decimal('0'),
#   'ipoing': Decimal('0'),
#   'ipoable': Decimal('0'),
#   'storage': Decimal('0'),
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AGLD',
#     'withdrawIntegerMultiple': Decimal('1E-8'),
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': Decimal('1.35'),
#     'withdrawMin': Decimal('2.7'),
#     'withdrawMax': Decimal('6973501'),
#     'withdrawInternalMin': Decimal('1E-8'),
# ...
